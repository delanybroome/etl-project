# %%
# Dependencies
import pandas as pd
import datetime

# %%
flu_data = "flu_ca_csv.csv"

# %%
flu_data_df = pd.read_csv(flu_data)

# %%
flu_data_df.head()
# Out:
#   REGION TYPE      REGION  YEAR  WEEK  TOTAL SPECIMENS  TOTAL A  TOTAL B  \
# 0      States  California  2019    40             1776       18       10
# 1      States  California  2019    41             1887       26       11
# 2      States  California  2019    42             1995       27       14
# 3      States  California  2019    43             1964       24       33
# 4      States  California  2019    44             2061       44       56
#
#    PERCENT POSITIVE  PERCENT A  PERCENT B
# 0              1.58       1.01       0.56
# 1              1.96       1.38       0.58
# 2              2.06       1.35       0.70
# 3              2.90       1.22       1.68
# 4              4.85       2.13       2.72

# %%
flu_data_df["Flu Cases"] = flu_data_df["TOTAL SPECIMENS"]* flu_data_df["PERCENT POSITIVE"] /100

# %%
flu_data_df.head()
# Out:
#   REGION TYPE      REGION  YEAR  WEEK  TOTAL SPECIMENS  TOTAL A  TOTAL B  \
# 0      States  California  2019    40             1776       18       10
# 1      States  California  2019    41             1887       26       11
# 2      States  California  2019    42             1995       27       14
# 3      States  California  2019    43             1964       24       33
# 4      States  California  2019    44             2061       44       56
#
#    PERCENT POSITIVE  PERCENT A  PERCENT B  Flu Cases
# 0              1.58       1.01       0.56    28.0608
# 1              1.96       1.38       0.58    36.9852
# 2              2.06       1.35       0.70    41.0970
# 3              2.90       1.22       1.68    56.9560
# 4              4.85       2.13       2.72    99.9585

# %%
flu_data_df["State"]= flu_data_df["REGION"]

# %%
cleaned_flu_data_df = flu_data_df(['State','Year','Week', 'Flue Cases']).copy()
cleaned_flu_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-ede484310769> in <module>
# ----> 1 cleaned_flu_data_df = flu_data_df(['State','Year','Week', 'Flue Cases']).copy()
#       2 cleaned_flu_data_df.head()
#
# TypeError: 'DataFrame' object is not callable
